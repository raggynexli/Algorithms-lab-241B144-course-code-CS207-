# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def sel_sort(nums):
    n = len(nums)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if nums[j] < nums[min_idx]:
                min_idx = j
        nums[i], nums[min_idx] = nums[min_idx], nums[i]
    return nums

def run_interaction():
    print("Let's sort some numbers.")
    try:
        n = int(input("How many numbers do you want? "))

        my_list = []
        print(f"Enter {n} numbers:")
        for _ in range(n):
            val = int(input("-> "))
            my_list.append(val)

        print("\nYour list:", my_list)

        start = time.time()
        sel_sort(my_list)
        end = time.time()

        print("Sorted:", my_list)
        print(f"Took: {end - start:.5f} seconds")

    except ValueError:
        print("Numbers only, please.")

def make_graph():
    print("\nGenerating the graph...")

    sizes = [100, 250, 500, 750, 1000, 1250, 1500, 2000]
    times = []

    for s in sizes:
        rand_list = [random.randint(0, 10000) for _ in range(s)]

        t1 = time.time()
        sel_sort(rand_list)
        t2 = time.time()

        times.append(t2 - t1)
        print(f"Done with size {s}")

    plt.figure(figsize=(10, 6))
    plt.plot(sizes, times, marker='o', color='red', label='Selection Sort')
    plt.title('Sort Speed')
    plt.xlabel('Items')
    plt.ylabel('Seconds')
    plt.grid(True)
    plt.legend()
    plt.show()
    run_interaction()
try:
    make_graph()
except:
    print("Graph needs matplotlib.")
# Out:
# Generating the graph...
# Done with size 100
# Done with size 250
# Done with size 500
# Done with size 750
# Done with size 1000
# Done with size 1250
# Done with size 1500
# Done with size 2000
# Let's sort some numbers.
# Graph needs matplotlib.

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def merge_sort(nums):
    if len(nums) > 1:
        mid = len(nums) // 2
        left = nums[:mid]
        right = nums[mid:]

        merge_sort(left)
        merge_sort(right)

        i = 0
        j = 0
        k = 0

        while i < len(left) and j < len(right):
            if left[i] <= right[j]:
                nums[k] = left[i]
                i += 1
            else:
                nums[k] = right[j]
                j += 1
            k += 1

        while i < len(left):
            nums[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            nums[k] = right[j]
            j += 1
            k += 1

    return nums

def run_interaction():
    print("Let's merge sort some numbers.")
    try:
        n = int(input("How many numbers do you want? "))

        my_list = []
        print(f"Enter {n} numbers:")
        for _ in range(n):
            val = int(input("-> "))
            my_list.append(val)

        print("\nYour list:", my_list)

        start = time.time()
        merge_sort(my_list)
        end = time.time()

        print("Sorted:", my_list)
        print(f"Took: {end - start:.5f} seconds")

    except ValueError:
        print("Numbers only, please.")

def make_graph():
    print("\nGenerating the graph...")

    sizes = [1000, 5000, 10000, 20000, 30000, 40000, 50000]
    times = []

    for s in sizes:
        rand_list = [random.randint(0, 100000) for _ in range(s)]

        t1 = time.time()
        merge_sort(rand_list)
        t2 = time.time()

        times.append(t2 - t1)
        print(f"Done with size {s}")

    plt.figure(figsize=(10, 6))
    plt.plot(sizes, times, marker='o', color='green', label='Merge Sort')

    plt.title('Merge Sort Speed')
    plt.xlabel('Items')
    plt.ylabel('Seconds')
    plt.grid(True)
    plt.legend()
    plt.show()

run_interaction()
try:
    make_graph()
except:
    print("Graph needs matplotlib.")
# Out:
# Let's merge sort some numbers.
# How many numbers do you want? 4
# Enter 4 numbers:
# -> 1,3,5,6
# Numbers only, please.
#
# Generating the graph...
# Done with size 1000
# Done with size 5000
# Done with size 10000
# Done with size 20000
# Done with size 30000
# Done with size 40000
# Done with size 50000

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def quick_sort(nums):
    if len(nums) <= 1:
        return nums
    else:
        pivot = nums[len(nums) // 2]
        left = [x for x in nums if x < pivot]
        middle = [x for x in nums if x == pivot]
        right = [x for x in nums if x > pivot]

        return quick_sort(left) + middle + quick_sort(right)

def run_interaction():
    print("Let's quick sort some numbers.")
    try:
        n = int(input("How many numbers do you want? "))

        my_list = []
        print(f"Enter {n} numbers:")
        for _ in range(n):
            val = int(input("-> "))
            my_list.append(val)

        print("\nYour list:", my_list)

        start = time.time()
        my_list = quick_sort(my_list)
        end = time.time()

        print("Sorted:", my_list)
        print(f"Took: {end - start:.5f} seconds")

    except ValueError:
        print("Numbers only, please.")

def make_graph():
    print("\nGenerating the graph...")

    sizes = [1000, 5000, 10000, 20000, 30000, 40000, 50000]
    times = []

    for s in sizes:
        rand_list = [random.randint(0, 100000) for _ in range(s)]

        t1 = time.time()
        quick_sort(rand_list)
        t2 = time.time()

        times.append(t2 - t1)
        print(f"Done with size {s}")

    plt.figure(figsize=(10, 6))
    plt.plot(sizes, times, marker='o', color='purple', label='Quick Sort')

    plt.title('Quick Sort Speed')
    plt.xlabel('Items')
    plt.ylabel('Seconds')
    plt.grid(True)
    plt.legend()
    plt.show()

run_interaction()
try:
    make_graph()
except:
    print("Graph needs matplotlib.")
# Out:
# Let's quick sort some numbers.
# How many numbers do you want? 3
# Enter 3 numbers:
# -> 1,2,4
# Numbers only, please.
#
# Generating the graph...
# Done with size 1000
# Done with size 5000
# Done with size 10000
# Done with size 20000
# Done with size 30000
# Done with size 40000
# Done with size 50000

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
import random
from datetime import datetime

ms = datetime.now().microsecond / 1000
random.seed(ms)

numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))

# %%
import copy
import timeit

a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quick_sort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    sel_sort(c)
    c_time.append((timeit.default_timer() - start_time) * 1000)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
